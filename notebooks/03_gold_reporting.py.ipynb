# %% [markdown]
# # Gold Reporting

# %% [markdown]
# ## Goal
# - create business facing output
# - daily order summary
# - order status summary

# %%
import yaml

# %%
config_path = "/Workspace/Users/adb-chonchanok@startsteps.org/de-mini-project-redcare-pharmacy/config/project_config.yml"

with open(config_path, "r") as f:
    config = yaml.safe_load(f)

# %%
catalog_name = config["catalog"]
schema_name = config["schema"]

silver_table = f"{catalog_name}.{schema_name}.{config['tables']['silver_orders']}"
gold_daily = f"{catalog_name}.{schema_name}.{config['tables']['gold_daily_orders']}"
gold_status = f"{catalog_name}.{schema_name}.{config['tables']['gold_status']}"

# %%
display(spark.table(gold_daily))

# %%
display(spark.table(gold_status))
